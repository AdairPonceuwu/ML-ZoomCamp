# %%
print('My email: 096734e4e895023ec23522abe7e0a0ffcec20c68')
# Out:
# My email: 096734e4e895023ec23522abe7e0a0ffcec20c68

# %%
import pandas as pd
import numpy as np
import wget

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
base = ['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
] 


data = df[base]

# %%
data.columns = data.columns.str.replace(' ', '_').str.lower()

# %%
data.head()
# Out:
#   make       model  year  engine_hp  engine_cylinders transmission_type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#   vehicle_style  highway_mpg  city_mpg
# 0         Coupe           26        19
# 1   Convertible           28        19
# 2         Coupe           28        20
# 3         Coupe           28        18
# 4   Convertible           28        18

# %%
data.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# dtype: int64

# %%
df.columns = df.columns.str.replace('MSRP', 'price')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity  price
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
data.transmission_type.unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
data.transmission_type.value_counts()
# Out:
# transmission_type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# dtype: object

# %%
numerical_columns = list(data.dtypes[data.dtypes == 'int64'].index)
numerical_columns.extend(list(data.dtypes[data.dtypes == 'float64'].index))
numerical_columns
# Out:
# ['year', 'highway_mpg', 'city_mpg', 'engine_hp', 'engine_cylinders']

# %%
corr = data[numerical_columns].corr ()
corr.style.background_gradient (cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_2df06_row0_col0, #T_2df06_row1_col1, #T_2df06_row2_col2, #T_2df06_row3_col3, #T_2df06_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2df06_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_2df06_row0_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_2df06_row0_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_2df06_row0_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_2df06_row1_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_2df06_row1_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_2df06_row1_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_2df06_row1_col4, #T_2df06_row2_col3, #T_2df06_row4_col0, #T_2df06_row4_col1, #T_2df06_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2df06_row2_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2df06_row2_col1 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_2df06_row2_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2df06_row3_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_2df06_row3_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2df06_row3_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_2df06_row3_col4 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_2df06_row4_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2df06">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2df06_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_2df06_level0_col1" class="col_heading level0 col1" >highway_mpg</th>
#       <th id="T_2df06_level0_col2" class="col_heading level0 col2" >city_mpg</th>
#       <th id="T_2df06_level0_col3" class="col_heading level0 col3" >engine_hp</th>
#       <th id="T_2df06_level0_col4" class="col_heading level0 col4" >engine_cylinders</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2df06_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_2df06_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2df06_row0_col1" class="data row0 col1" >0.258240</td>
#       <td id="T_2df06_row0_col2" class="data row0 col2" >0.198171</td>
#       <td id="T_2df06_row0_col3" class="data row0 col3" >0.338714</td>
#       <td id="T_2df06_row0_col4" class="data row0 col4" >-0.040708</td>
#     </tr>
#     <tr>
#       <th id="T_2df06_level0_row1" class="row_heading level0 row1" >highway_mpg</th>
#       <td id="T_2df06_row1_col0" class="data row1 col0" >0.258240</td>
#       <td id="T_2df06_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2df06_row1_col2" class="data row1 col2" >0.886829</td>
#       <td id="T_2df06_row1_col3" class="data row1 col3" >-0.415707</td>
#       <td id="T_2df06_row1_col4" class="data row1 col4" >-0.614541</td>
#     </tr>
#     <tr>
#       <th id="T_2df06_level0_row2" class="row_heading level0 row2" >city_mpg</th>
#       <td id="T_2df06_row2_col0" class="data row2 col0" >0.198171</td>
#       <td id="T_2df06_row2_col1" class="data row2 col1" >0.886829</td>
#       <td id="T_2df06_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2df06_row2_col3" class="data row2 col3" >-0.424918</td>
#       <td id="T_2df06_row2_col4" class="data row2 col4" >-0.587306</td>
#     </tr>
#     <tr>
#       <th id="T_2df06_level0_row3" class="row_heading level0 row3" >engine_hp</th>
#       <td id="T_2df06_row3_col0" class="data row3 col0" >0.338714</td>
#       <td id="T_2df06_row3_col1" class="data row3 col1" >-0.415707</td>
#       <td id="T_2df06_row3_col2" class="data row3 col2" >-0.424918</td>
#       <td id="T_2df06_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2df06_row3_col4" class="data row3 col4" >0.774851</td>
#     </tr>
#     <tr>
#       <th id="T_2df06_level0_row4" class="row_heading level0 row4" >engine_cylinders</th>
#       <td id="T_2df06_row4_col0" class="data row4 col0" >-0.040708</td>
#       <td id="T_2df06_row4_col1" class="data row4 col1" >-0.614541</td>
#       <td id="T_2df06_row4_col2" class="data row4 col2" >-0.587306</td>
#       <td id="T_2df06_row4_col3" class="data row4 col3" >0.774851</td>
#       <td id="T_2df06_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
mean = df['price'].mean()
df.loc[df.price>mean,'above_average'] = 1
df.loc[df.price<mean,'above_average'] = 0

df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity  price  above_average
# 0               26        19        3916  46135            1.0
# 1               28        19        3916  40650            1.0
# 2               28        20        3916  36350            0.0
# 3               28        18        3916  29450            0.0
# 4               28        18        3916  34500            0.0
# ...            ...       ...         ...    ...            ...
# 11909           23        16         204  46120            1.0
# 11910           23        16         204  56670            1.0
# 11911           23        16         204  50620            1.0
# 11912           23        16         204  50920            1.0
# 11913           26        17          61  28995            0.0
#
# [11914 rows x 17 columns]

# %%
df.above_average = df.above_average.round(0).astype(int)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity  price  above_average
# 0               26        19        3916  46135              1
# 1               28        19        3916  40650              1
# 2               28        20        3916  36350              0
# 3               28        18        3916  29450              0
# 4               28        18        3916  34500              0
# ...            ...       ...         ...    ...            ...
# 11909           23        16         204  46120              1
# 11910           23        16         204  56670              1
# 11911           23        16         204  50620              1
# 11912           23        16         204  50920              1
# 11913           26        17          61  28995              0
#
# [11914 rows x 17 columns]

# %%
data = data.assign(above_average=df['above_average'])
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19              1
# 1                MANUAL    Convertible           28        19              1
# 2                MANUAL          Coupe           28        20              0
# 3                MANUAL          Coupe           28        18              0
# 4                MANUAL    Convertible           28        18              0
# ...                 ...            ...          ...       ...            ...
# 11909         AUTOMATIC  4dr Hatchback           23        16              1
# 11910         AUTOMATIC  4dr Hatchback           23        16              1
# 11911         AUTOMATIC  4dr Hatchback           23        16              1
# 11912         AUTOMATIC  4dr Hatchback           23        16              1
# 11913         AUTOMATIC          Sedan           26        17              0
#
# [11914 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(data, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = df_train.above_average.values
y_val = df_val.above_average.values
y_test = df_test.above_average.values

del df_train['above_average']
del df_val['above_average']
del df_test['above_average']

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7148, 2383, 2383)

# %%
from sklearn.metrics import mutual_info_score

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.make),2)
# Out:
# 0.24

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.model),2)
# Out:
# 0.46

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.transmission_type),2)
# Out:
# 0.02

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.vehicle_style),2)
# Out:
# 0.08

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# above_average          int32
# dtype: object

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders','highway_mpg','city_mpg']
categorical = ['make','model','transmission_type','vehicle_style']

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict_proba(X_val)[:, 1]
price = (y_pred >= 0.5)
(y_val == price).mean()
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = price.astype(int)
df_pred['actual'] = y_val
df_pred['correct'] = df_pred.prediction == df_pred.actual
all_features = round(df_pred.correct.mean(),2)
all_features
# Out:
# 0.95

# %%
list_accu_ca = ['year','engine_hp', 'transmission_type', 'city_mpg']
for i in list_accu_ca:
    if i in numerical:
        print("Numerical:",i)
        numerical.remove(i)
        dv = DictVectorizer(sparse=False)

        train_dict = df_train[categorical + numerical].to_dict(orient='records')
        X_train = dv.fit_transform(train_dict)

        val_dict = df_val[categorical + numerical].to_dict(orient='records')
        X_val = dv.transform(val_dict)
        
        model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        
        y_pred = model.predict_proba(X_val)[:, 1]
        price = (y_pred >= 0.5)
        (y_val == price).mean()
        df_pred = pd.DataFrame()
        df_pred['probability'] = y_pred
        df_pred['prediction'] = price.astype(int)
        df_pred['actual'] = y_val
        df_pred['correct'] = df_pred.prediction == df_pred.actual
        print(all_features-df_pred.correct.mean())
        numerical.append(i)
    else:
        print("Categorial:",i)
        categorical.remove(i)
        dv = DictVectorizer(sparse=False)

        train_dict = df_train[categorical + numerical].to_dict(orient='records')
        X_train = dv.fit_transform(train_dict)

        val_dict = df_val[categorical + numerical].to_dict(orient='records')
        X_val = dv.transform(val_dict)
        
        model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        
        y_pred = model.predict_proba(X_val)[:, 1]
        price = (y_pred >= 0.5)
        (y_val == price).mean()
        df_pred = pd.DataFrame()
        df_pred['probability'] = y_pred
        df_pred['prediction'] = price.astype(int)
        df_pred['actual'] = y_val
        df_pred['correct'] = df_pred.prediction == df_pred.actual
        print(all_features-df_pred.correct.mean())
        categorical.append(i)
# Out:
# Numerical: year
# 0.0020352496852705793
# Numerical: engine_hp
# 0.02217792698279475
# Categorial: transmission_type
# 0.004972723457826178
# Numerical: city_mpg
# 0.01756189676877884

# %%
data = data.assign(above_average=df['price'])
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19          46135
# 1                MANUAL    Convertible           28        19          40650
# 2                MANUAL          Coupe           28        20          36350
# 3                MANUAL          Coupe           28        18          29450
# 4                MANUAL    Convertible           28        18          34500
# ...                 ...            ...          ...       ...            ...
# 11909         AUTOMATIC  4dr Hatchback           23        16          46120
# 11910         AUTOMATIC  4dr Hatchback           23        16          56670
# 11911         AUTOMATIC  4dr Hatchback           23        16          50620
# 11912         AUTOMATIC  4dr Hatchback           23        16          50920
# 11913         AUTOMATIC          Sedan           26        17          28995
#
# [11914 rows x 10 columns]

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders','highway_mpg','city_mpg','above_average']
df_full_train, df_test = train_test_split(data[numerical], test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train_orig = df_train.above_average.values
y_val_orig = df_val.above_average.values
y_test_orig = df_test.above_average.values

y_train = np.log1p(y_train_orig)
y_val = np.log1p(y_val_orig)
y_test = np.log1p(y_test_orig)

del df_train['above_average']
del df_val['above_average']
del df_test['above_average']

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from math import sqrt

# %%
alphas = [0, 0.01, 0.1, 1, 10]
rmse_scores = []
for alpha in alphas:

    ridge_model = Ridge(solver='sag', alpha=alpha, random_state=42)

    ridge_model.fit(df_train.values, y_train)

    y_pred = ridge_model.predict(df_val.values)

    rmse = sqrt(mean_squared_error(y_test, y_pred))
    
    rmse = round(rmse, 3)

    rmse_scores.append(rmse)

rmse_scores
# Out:
# [1.495, 1.495, 1.495, 1.495, 1.495]
