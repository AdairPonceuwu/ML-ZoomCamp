# %%
print('My email: 096734e4e895023ec23522abe7e0a0ffcec20c68')
# Out:
# My email: 096734e4e895023ec23522abe7e0a0ffcec20c68

# %%
import pandas as pd
import numpy as np
import wget

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
base = ['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
'MSRP'] 


data = df[base]

# %%
data.columns = data.columns.str.replace(' ', '_').str.lower()

# %%
data.columns = data.columns.str.replace('msrp', 'price')

# %%
data.head()
# Out:
#   make       model  year  engine_hp  engine_cylinders transmission_type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#   vehicle_style  highway_mpg  city_mpg  price
# 0         Coupe           26        19  46135
# 1   Convertible           28        19  40650
# 2         Coupe           28        20  36350
# 3         Coupe           28        18  29450
# 4   Convertible           28        18  34500

# %%
data.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# price                 0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# price                0
# dtype: int64

# %%
data.transmission_type.unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
data.transmission_type.value_counts()
# Out:
# transmission_type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# price                  int64
# dtype: object

# %%
numerical_columns = list(data.dtypes[data.dtypes == 'int64'].index)
numerical_columns.extend(list(data.dtypes[data.dtypes == 'float64'].index))
numerical_columns
# Out:
# ['year', 'highway_mpg', 'city_mpg', 'price', 'engine_hp', 'engine_cylinders']

# %%
corr = data[numerical_columns].corr ()
corr.style.background_gradient (cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_7067e_row0_col0, #T_7067e_row1_col1, #T_7067e_row2_col2, #T_7067e_row3_col3, #T_7067e_row4_col4, #T_7067e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7067e_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_7067e_row0_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_7067e_row0_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7067e_row0_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_7067e_row0_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_7067e_row1_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_7067e_row1_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_7067e_row1_col3, #T_7067e_row1_col5, #T_7067e_row2_col3, #T_7067e_row2_col4, #T_7067e_row5_col0, #T_7067e_row5_col1, #T_7067e_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7067e_row1_col4 {
# ...

# %%
mean = data['price'].mean()
data.loc[data.price>mean,'above_average'] = 1
data.loc[data.price<mean,'above_average'] = 0

data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price  \
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# ...

# %%
data.above_average = data.above_average.round(0).astype(int)
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price  \
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(data, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = df_train.above_average.values
y_val = df_val.above_average.values
y_test = df_test.above_average.values

del df_train['above_average']
del df_val['above_average']
del df_test['above_average']

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7148, 2383, 2383)

# %%
from sklearn.metrics import mutual_info_score

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.make),2)
# Out:
# 0.24

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.model),2)
# Out:
# 0.46

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.transmission_type),2)
# Out:
# 0.02

# %%
round(mutual_info_score(df_full_train.above_average, df_full_train.vehicle_style),2)
# Out:
# 0.08

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# price                  int64
# above_average          int32
# dtype: object

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders','highway_mpg','city_mpg']
categorical = ['make','model','transmission_type','vehicle_style']

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
X_train
# Out:
# array([[1.500e+01, 6.000e+00, 2.250e+02, ..., 0.000e+00, 0.000e+00,
#         2.011e+03],
#        [1.700e+01, 6.000e+00, 2.760e+02, ..., 0.000e+00, 0.000e+00,
#         2.009e+03],
#        [1.200e+01, 1.000e+01, 5.700e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        ...,
#        [1.700e+01, 6.000e+00, 2.600e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        [1.900e+01, 4.000e+00, 1.360e+02, ..., 0.000e+00, 0.000e+00,
#         1.993e+03],
#        [1.700e+01, 6.000e+00, 3.650e+02, ..., 1.000e+00, 0.000e+00,
#         2.015e+03]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict_proba(X_val)[:, 1]
price = (y_pred >= 0.5)
(y_val == price).mean()
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = price.astype(int)
df_pred['actual'] = y_val
df_pred['correct'] = df_pred.prediction == df_pred.actual
all_features = round(df_pred.correct.mean(),2)
all_features
# Out:
# 0.95

# %%
list_accu_ca = ['year','engine_hp', 'transmission_type', 'city_mpg']
for i in list_accu_ca:
    if i in numerical:
        print("Numerical:",i)
        numerical.remove(i)
        dv = DictVectorizer(sparse=False)

        train_dict = df_train[categorical + numerical].to_dict(orient='records')
        X_train = dv.fit_transform(train_dict)

        val_dict = df_val[categorical + numerical].to_dict(orient='records')
        X_val = dv.transform(val_dict)
        
        model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        
        y_pred = model.predict_proba(X_val)[:, 1]
        price = (y_pred >= 0.5)
        (y_val == price).mean()
        df_pred = pd.DataFrame()
        df_pred['probability'] = y_pred
        df_pred['prediction'] = price.astype(int)
        df_pred['actual'] = y_val
        df_pred['correct'] = df_pred.prediction == df_pred.actual
        print(all_features-df_pred.correct.mean())
        numerical.append(i)
    else:
        print("Categorial:",i)
        categorical.remove(i)
        dv = DictVectorizer(sparse=False)

        train_dict = df_train[categorical + numerical].to_dict(orient='records')
        X_train = dv.fit_transform(train_dict)

        val_dict = df_val[categorical + numerical].to_dict(orient='records')
        X_val = dv.transform(val_dict)
        
        model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        
        y_pred = model.predict_proba(X_val)[:, 1]
        price = (y_pred >= 0.5)
        (y_val == price).mean()
        df_pred = pd.DataFrame()
        df_pred['probability'] = y_pred
        df_pred['prediction'] = price.astype(int)
        df_pred['actual'] = y_val
        df_pred['correct'] = df_pred.prediction == df_pred.actual
        print(all_features-df_pred.correct.mean())
        categorical.append(i)
# Out:
# Numerical: year
# 0.0020352496852705793
# Numerical: engine_hp
# 0.02217792698279475
# Categorial: transmission_type
# 0.004972723457826178
# Numerical: city_mpg
# 0.01756189676877884

# %%
del data['above_average']
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# ...

# %%
df_full_train, df_test = train_test_split(data, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train_orig = df_train.price.values
y_val_orig = df_val.price.values
y_test_orig = df_test.price.values

y_train = np.log1p(y_train_orig)
y_val = np.log1p(y_val_orig)
y_test = np.log1p(y_test_orig)

del df_train['price']
del df_val['price']
del df_test['price']

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7148, 2383, 2383)

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders','highway_mpg','city_mpg']
categorical = ['make','model','transmission_type','vehicle_style']

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
X_train
# Out:
# array([[1.500e+01, 6.000e+00, 2.250e+02, ..., 0.000e+00, 0.000e+00,
#         2.011e+03],
#        [1.700e+01, 6.000e+00, 2.760e+02, ..., 0.000e+00, 0.000e+00,
#         2.009e+03],
#        [1.200e+01, 1.000e+01, 5.700e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        ...,
#        [1.700e+01, 6.000e+00, 2.600e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        [1.900e+01, 4.000e+00, 1.360e+02, ..., 0.000e+00, 0.000e+00,
#         1.993e+03],
#        [1.700e+01, 6.000e+00, 3.650e+02, ..., 1.000e+00, 0.000e+00,
#         2.015e+03]])

# %%
X_val
# Out:
# array([[2.300e+01, 4.000e+00, 2.100e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03],
#        [1.700e+01, 6.000e+00, 3.540e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03],
#        [2.200e+01, 4.000e+00, 1.400e+02, ..., 1.000e+00, 0.000e+00,
#         2.005e+03],
#        ...,
#        [1.200e+01, 6.000e+00, 1.900e+02, ..., 0.000e+00, 0.000e+00,
#         2.003e+03],
#        [1.400e+01, 8.000e+00, 4.300e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03],
#        [1.800e+01, 6.000e+00, 3.210e+02, ..., 1.000e+00, 0.000e+00,
#         2.015e+03]])

# %%
y_train
# Out:
# array([10.42228135, 10.17526888, 12.42118806, ..., 10.25224121,
#         7.60140233, 10.60214453])

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from math import sqrt

# %%
alphas = [0, 0.01, 0.1, 1, 10]
rmse_scores = []
for alpha in alphas:

    ridge_model = Ridge(solver='sag', alpha=alpha, max_iter=100, random_state=42)

    ridge_model.fit(X_train, y_train)

    y_pred = ridge_model.predict(X_val)

    rmse = sqrt(mean_squared_error(y_test, y_pred))
    
    rmse = round(rmse, 3)

    rmse_scores.append(rmse)

rmse_scores
# Out:
# D:\Anaconda\envs\ml-zoomcamp\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# D:\Anaconda\envs\ml-zoomcamp\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# D:\Anaconda\envs\ml-zoomcamp\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# D:\Anaconda\envs\ml-zoomcamp\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# D:\Anaconda\envs\ml-zoomcamp\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [1.4942529267172155,
#  1.4942529177475352,
#  1.4942528370209565,
# ...
